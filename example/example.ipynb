# %%
import sys
print(sys.path)
# Out:
# ['/home/aletia/wsl_code/geohubLA_data_collection/example', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/home/aletia/wsl_code/geohubLA_data_collection/myenv/lib/python3.10/site-packages']

# %%
# check file size
folder_path = 'data'

# %%
# Load and plot the shapefile
gdf = gpd.read_file(f"{folder_path}/output_shapefile_{district}.shp")


# Plotting
fig, ax = plt.subplots(figsize=(10, 10)) 
gdf.plot(ax=ax, color='blue') 

ax.set_title("Sample Districts")
plt.show()
